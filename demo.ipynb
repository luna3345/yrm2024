# %%
import skimage

# load image, filter it and threshold it to create a mask
image = skimage.io.imread('drive/satellite.tif', plugin='imageio')
# image = skimage.io.imread('https://raw.githubusercontent.com/guiwitz/YRD2024/main/satellite.tif', plugin='imageio')
image_gauss = skimage.filters.gaussian(image, preserve_range=True)
image_mask = image_gauss > 1000

skimage.io.imshow_collection([image, image_mask]);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import skimage
#       3 # load image, filter it and threshold it to create a mask
# ----> 4 image = skimage.io.imread('drive/satellite.tif', plugin='imageio')
#       5 # image = skimage.io.imread('https://raw.githubusercontent.com/guiwitz/YRD2024/main/satellite.tif', plugin='imageio')
#       6 image_gauss = skimage.filters.gaussian(image, preserve_range=True)
#
# File /lib/python3.11/site-packages/skimage/io/_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# ...
